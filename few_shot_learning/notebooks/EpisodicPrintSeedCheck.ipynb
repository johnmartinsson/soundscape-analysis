# %%
path_0 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/seedtest7_pair0_print/sampler.txt'
path_1 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/seedtest7_pair1_print/sampler.txt'

f_0 = open(path_0, 'r')
f_1 = open(path_1, 'r')

# %%
next(f_0) == next(f_1)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_2233590/1587457291.py in <module>
# ----> 1 next(f_0) == next(f_1)
#
# StopIteration:

# %%
print(next(f_0)[0:500])
print(next(f_1)[0:500])
# Out:
# tensor([ 0,  3,  4, 15, 17, 14, 16,  9,  2,  8])tensor([3389, 1302, 5765,  793, 5622, 3249, 4363, 4203, 1657, 2831])tensor([1960, 3047,  138,  730, 4610, 3603, 1376, 2758, 5063, 2830])tensor([ 701, 5748, 1983,  554, 3662, 5370,  303, 3005, 4881, 1671])tensor([4667,  533, 1000,  628, 3908, 1838, 3406, 5170, 4176, 1758])tensor([1214, 5036, 3748, 1958, 5720,  892,  591, 5557, 5401, 3930])tensor([2034, 4770, 3813, 2278, 4129,  466, 5291, 3096, 3153, 2325])tensor([ 624, 4608, 1581, 4576, 3178,  103,
# ...

# %%
'aaaa33' == 'aaaa33'
# Out:
# True

# %%
import sys
sys.path.append('..')

import torch
import models.prototypical as prot

# %%
model = prot.Protonet()

param = model.parameters()

# %%
next(param)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_2261762/743486748.py in <module>
# ----> 1 next(param)
#
# StopIteration:

# %%
path_0 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/grad_test_pair0/grad_first_batch.txt'
path_1 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/grad_test_pair1/grad_first_batch.txt'

f_0 = open(path_0, 'r')
f_1 = open(path_1, 'r')

# %%
i = 0

while True:
    try:
        print(next(f_0) == next(f_1))
        i += 1
    except:
        break
print(i)
# Out:
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# ...

# %%
path_0 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/grad_test_pair0/first_batch.txt'
path_1 = '/home/willbo/repos/soundscape-analysis/few_shot_learning/outputs/grad_test_pair1/first_batch.txt'

f_0 = open(path_0, 'r')
f_1 = open(path_1, 'r')

# %%
i = 0

while True:
    try:
        print(next(f_0) == next(f_1))
        i += 1
    except:
        break
print(i)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
s = set(labels)
{label:index for index, label in enumerate(s)}
# Out:
# {'b': 0, 'e': 1, 'd': 2, 'g': 3, 'c': 4, 'a': 5, 'f': 6}
